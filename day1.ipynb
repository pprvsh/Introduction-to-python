# %%
print("prasamsha")
# Out:
# prasamsha

# %%
### About jupyter notebookLearn Python
"Python is a popular programming language. Python can be used on a server to create web applications. Start learning Python now"

# %%
y="5"
type(y)
# Out:
# str

# %%
y=5
type(y)
# Out:
# int

# %%
x=5
y=10
z=x+y
print(z)
# Out:
# 15

# %%
x="5"
y="10"
z=x+y
print(z)
# Out:
# 510

# %%
x=5
y="10"
z=x+y
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 x=5
#       2 y="10"
# ----> 3 z=x+y
#       4 print(z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
a=int(y)

# %%
a+x
# Out:
# 15

# %%
b=str(x)

# %%
b+x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 b+x
#
# NameError: name 'b' is not defined

# %%
type(b+x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 type(b+x)
#
# NameError: name 'b' is not defined

# %%
age=input("enter the age:")
# Out:
# enter the age: 10

# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 5

# %%
type(age)

# %%
age=input("enter the age")

# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 100

# %%
type(age)
# Out:
# int

# %%
age=input("enter the age")
# Out:
# enter the age 20

# %%
type(age)
# Out:
# str

# %%
var=6
float1=5.5
result=var+float1
print(result)
# Out:
# 11.5

# %%
name="prasamsha"
surname="upp"
age=23

# %%
#fstring
print(f"my name is {prasamshsa} and surname {panday}")
print("my name is ",name,"and surname",surname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 #fstring
# ----> 2 print(f"my name is {prasamshsa} and surname {panday}")
#       3 print("my name is ",name,"and surname",surname)
#
# NameError: name 'prasamshsa' is not defined

# %%
#fstring
print(f"My name is {name} and surname {surname}")

print("My name is", name,"and surname", surname)
# Out:
# My name is prasamsha and surname upp
# My name is prasamsha and surname upp

# %%
#format

print("My name is {} {}".format(name, surname))
print("My name is {} {}".format("prasamsha", "Sharma"))
# Out:
# My name is prasamsha upp
# My name is prasamsha Sharma

# %%
a = "50"
z = 1j

b = 3.5
is_student = True

# %%
type(z)
# Out:
# complex

# %%
type(is_student)
# Out:
# bool

# %%
b="namaste"
a="hell0"
c=a+b
print(c)
# Out:
# hell0namaste

# %%
a="11"
b="23"
c=a+b
print(c)
# Out:
# 1123

# %%
a=6
b=10

# %%
type(a)
# Out:
# int

# %%
query=input("enter your age")
# Out:
# enter your age 10

# %%
type(query)
# Out:
# str

# %%
query=input("enter your name")
# Out:
# enter your name "prasamsha"

# %%
type(query)
# Out:
# str

# %%
 a, b = 3, 4
a=b
temp=3
b=temp
b=a
#a,b=b,a
# Out:
#   Cell In[49], line 1
#     a, b = 3, 4
#     ^
# IndentationError: unexpected indent

# %%
a,b=3,4
a,b=b,a

# %%
a
# Out:
# 4

# %%
a,b=3,4
a,b=b,a

# %%
a
# Out:
# 4

# %%
x=y=z="women"

# %%
print(f"the value of x {}, the value of y {} and the value of z{}")
# Out:
#   Cell In[53], line 1
#     print(f"the value of x {}, the value of y {} and the value of z{}")
#                             ^
# SyntaxError: f-string: valid expression required before '}'
